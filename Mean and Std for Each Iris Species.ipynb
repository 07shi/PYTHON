# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Mean%20and%20Std%20for%20Each%20Iris%20Species.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\nMean for each species")
print(data.groupby('species').mean())

print("\nStandard deviation for each species")
print(data.groupby('species').std())
# Out:
# Mean for each species
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# Standard deviation for each species
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa               0.352490          0.379064           0.173664
# versicolor           0.516171          0.313798           0.469911
# virginica            0.635880          0.322497           0.551895
#
#             petal width (cm)
# species
# setosa              0.105386
# versicolor          0.197753
# virginica           0.274650
