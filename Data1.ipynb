# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Data1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# First DataFrame
data = {
    "Name": ['Jai','Prince','Gaurav','Anuj'],
    "Age": [27,24,22,32],
    "Address": ['Delhi','Kanpur','Allahabad','Kannauj'],
    "Quali": ["M Sc",'MA','MCA',"Phd"]
}

df = pd.DataFrame(data)
print(df[['Name','Quali']])

# Second Part
data = pd.read_csv('nba.csv', index_col='name')

first = data.loc["Avery Bradley"]
second = data.loc['R.J. Hunter']

print(first, '\n\n\n', second)
# Out:
#      Name Quali
# 0     Jai  M Sc
# 1  Prince    MA
# 2  Gaurav   MCA
# 3    Anuj   Phd
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1585897106.py in <cell line: 0>()
#      13
#      14 # Second Part
# ---> 15 data = pd.read_csv('nba.csv', index_col='name')
#      16
#      17 first = data.loc["Avery Bradley"]
#
# ...
