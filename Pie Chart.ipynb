# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Pie%20Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
species_count.plot(kind='pie', autopct='%1.1f%%')
plt.title("Species Distribution")
plt.ylabel("")
plt.show()
