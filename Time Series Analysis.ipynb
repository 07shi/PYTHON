# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Time%20Series%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats import boxcox
date = pd.date_range(start='2020-01-01', periods=60, freq='M')
sales = np.random.randint(200,500,60)

df = pd.DataFrame({
    "Date":date,
    "Sales":sales
})

df.set_index("Date", inplace=True)

print(df.head())
# Out:
#             Sales
# Date
# 2020-01-31    359
# 2020-02-29    379
# 2020-03-31    295
# 2020-04-30    204
# 2020-05-31    297
# /tmp/ipykernel_554/1840158663.py:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date = pd.date_range(start='2020-01-01', periods=60, freq='M')
